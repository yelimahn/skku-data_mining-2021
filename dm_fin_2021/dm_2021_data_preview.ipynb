# %%
import pandas as pd

# %%
meta = pd.read_json('./dataset/fandom_meta_2018.json')
meta.head()
# Out:
#    fandom_name     chart_name                 agent  year(debut)  post_num
# 0        6kies           None      YG Entertainment         1997    293338
# 1       acejun           None      Beat Interactive         2017      2106
# 2  ahnhyungsub           None  Yuehua Entertainment         2017     98096
# 3      anyujin  IZ*ONE (아이즈원)        Off The Record         2018     34362
# 4          aoa            AOA     FNC Entertainment         2012     39128

# %% [markdown]
# 팬덤 메타정보
# -  fandom_name: 해당 팬덤의 노드이름
# -  chart_name:  차트데이터의 아티스트명
# -  agent: 소속사  (2019년 기준)
# -  year(debut): 데뷔년도
# -  post_num:  팬  커뮤니티내 전체 게시글 수 (1년치,  도움게시글 제외)

# %%
nodes = pd.read_csv('./dataset/fandom_nodes_2018.csv')
nodes.head(5)
# Out:
#   fandom_id            fandom_name  nov_post  dec_post  nov_support  \
# 0  000115sh            KIM SU-HYUN        68       159            0
# 1     10520       MOE GOTO / AKB48      1998      1760          179
# 2  19980917    KIM DONG-HYUN / MXM       718       423          349
# 3       2PM                    2PM         0         1            0
# 4     6kies  SECHSKIES (disbanded)     24502     16726         2981
#
#    dec_support  type
# 0           10     0
# 1          175     0
# 2          194     1
# 3            1     1
# 4         1815     1

# %% [markdown]
# 팬덤 활동정보
# - fandom_id: 팬덤의 노드이름
# - fandom_name: 팬덤  이름
# - nov_post:  11월 팬  커뮤니티 내 총 게시글 수
# - dec_post:  12월 팬  커뮤니티 내 총 게시글 수
# - nov_support:  11월 supporting 수
# - dec_support:  12월 supporting 수

# %%
edges = pd.read_csv('./dataset/fandom_edges_2018.csv')
edges.head(5)
# Out:
#    source         target  nov_support  dec_support
# 0  010520         dongho          1.0          0.0
# 1  010520           erii          3.0          0.0
# 2  010520     kimnayoung          1.0          0.0
# 3  010520  matsui_jurina          3.0          0.0
# 4  010520   miyazakimiho         47.0         23.0

# %% [markdown]
# 팬덤간 도움 정보
# - source: source node
# - target: taget node
# - nov_support: 11월 도움 횟수
# - dec_support:  12월 도움 횟수

# %%
monthly_chart = pd.read_json('./dataset/monthly_chart_2018.json')
monthly_chart.tail()
# Out:
#       rank                   title               artist  \
# 1195    96  I Was Born To Love You                Queen
# 1196    97                HandClap  Fitz & The Tantrums
# 1197    98                      동화                 멜로망스
# 1198    99                  Deeper      Wanna One (워너원)
# 1199   100                     You                 멜로망스
#
#                                album   start     end
# 1195                  Made In Heaven  201812  201812
# 1196  Fitz and The Tantrums (Deluxe)  201812  201812
# 1197                  The Fairy Tale  201812  201812
# 1198        1¹¹=1 (POWER OF DESTINY)  201812  201812
# 1199           투유 프로젝트 - 슈가맨2 Part.2  201812  201812

# %% [markdown]
# 월간 음원 차트
# - start: 차트 진입 주의 월
# -  end:  차트 진입 주의 월
